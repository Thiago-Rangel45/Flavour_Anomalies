# %%
import uproot
import zfit
import pandas as pd
import numpy as np
import awkward as ak
import matplotlib.pyplot as plt
import mplhep as hep
import os
import joblib
import json
import warnings
from xgboost import XGBClassifier
from sklearn.model_selection import (train_test_split, GridSearchCV, StratifiedKFold, learning_curve)
from sklearn.metrics import (roc_curve, auc, precision_recall_curve, average_precision_score, confusion_matrix,
                             ConfusionMatrixDisplay, classification_report, accuracy_score, f1_score)
# Out:
# /home/tandrade/.local/lib/python3.9/site-packages/zfit/__init__.py:63: UserWarning: TensorFlow warnings are by default suppressed by zfit. In order to show them, set the environment variable ZFIT_DISABLE_TF_WARNINGS=0. In order to suppress the TensorFlow warnings AND this warning, set ZFIT_DISABLE_TF_WARNINGS=1.
#   warnings.warn(

# %%
signal_path = "/home/tandrade/Flavour_Anomalies/Data/MC.root"
bg_path     = "/home/tandrade/Flavour_Anomalies/Data/Data.root"
tree_name   = "tree_ML"

# %%
features = [
    'BToTrkTrkMuMu_l_xy_sig_good',
    'BToTrkTrkMuMu_dca_sig_good',
    'BToTrkTrkMuMu_trk1_dca_sig_good',
    'BToTrkTrkMuMu_trk2_dca_sig_good',
    'BToTrkTrkMuMu_fit_ditrack_mass_Kpi_good',
    'BToTrkTrkMuMu_fit_pt_good',
    'BToTrkTrkMuMu_fit_cos2D_good',
    'BToTrkTrkMuMu_svprob_good'
]

cut_features = [
    'MuMu_mass_idx_good', 
    'BToTrkTrkMuMu_fit_mass_Kpi_good'
]

# %%
signal_file = uproot.open(signal_path)[tree_name]
background_file = uproot.open(bg_path)[tree_name]

cols_to_load = features + cut_features

signal_ak = signal_file.arrays(cols_to_load, library="ak")
background_ak = background_file.arrays(cols_to_load, library="ak")

signal_df = ak.to_dataframe(signal_ak)
background_df = ak.to_dataframe(background_ak)

# %%
signal_df["label"] = 1
background_df["label"] = 0

# %%
df = pd.concat([signal_df, background_df], ignore_index=True)

cut_mass_B = (df['BToTrkTrkMuMu_fit_mass_Kpi_good'] > 5.0) & (df['BToTrkTrkMuMu_fit_mass_Kpi_good'] < 5.6)
cut_mass_MuMu = ( ((df['MuMu_mass_idx_good'] > 1.0) & (df['MuMu_mass_idx_good'] < 2.9)) | ((df['MuMu_mass_idx_good'] > 4.0) & (df['MuMu_mass_idx_good'] < 4.8)) )
#cut_HLT = df['HLT_DoubleMu4_LowMass_Displaced'] = 1

is_signal_label = (df['label'] == 1)
signal_region_cut = (df['BToTrkTrkMuMu_fit_mass_Kpi_good'] > 5.133542769) & (df['BToTrkTrkMuMu_fit_mass_Kpi_good'] < 5.416657231)
keep_signal = is_signal_label & signal_region_cut

is_bkg_label = (df['label'] == 0)
left_band = (df['BToTrkTrkMuMu_fit_mass_Kpi_good'] > 5.0) & (df['BToTrkTrkMuMu_fit_mass_Kpi_good'] <= 5.133542769)
right_band = (df['BToTrkTrkMuMu_fit_mass_Kpi_good'] >= 5.416657231) & (df['BToTrkTrkMuMu_fit_mass_Kpi_good'] < 5.6)
keep_bkg = is_bkg_label & (left_band | right_band)

final_selection_mask = (keep_signal | keep_bkg) & cut_mass_MuMu
df_cut = df[final_selection_mask]

# %%
model = joblib.load("final_bdt_model.joblib")

# %%
probabilities = model.predict_proba(df_cut[features])[:, 1]
df_cut['bdt_score'] = probabilities
# Out:
# /tmp/ipykernel_5184/819098696.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cut['bdt_score'] = probabilities

# %%
df = df_cut.copy()

# %%
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np

hep.style.use(hep.style.CMS)

L_data_fb = 5.01
sigma_pb  = 17370000 
BR        = 6.30e-7
N_mc_gen  = 949314      

L_data_pb = L_data_fb * 1000 
n_expected = L_data_pb * sigma_pb * BR
scale_factor = n_expected / N_mc_gen

print(f"Eventos esperados: {n_expected:.2f}")
print(f"Scale Factor: {scale_factor:.4f}")

var_name = 'BToTrkTrkMuMu_fit_mass_Kpi_good'
corte_bdt = 0.

mask_bkg = (df['label'] == 0) & (df['bdt_score'] > corte_bdt)
data_bkg = df[mask_bkg][var_name]

mask_sig = (df['label'] == 1) & (df['bdt_score'] > corte_bdt)
data_sig = df[mask_sig][var_name]

xmin, xmax = data_bkg.min(), data_bkg.max() 
bins = np.linspace(xmin, xmax, 60)
h_bkg, _ = np.histogram(data_bkg, bins=bins)

weights_sig = np.full(len(data_sig), scale_factor)
h_sig, _ = np.histogram(data_sig, bins=bins, weights=weights_sig)
fig, ax = plt.subplots(figsize=(10, 8))

hep.histplot(
    h_bkg,
    bins=bins,
    ax=ax,
    histtype='fill',
    color='gray',
    alpha=0.5,
    edgecolor='black',
    label=f'Background (Data {L_data_fb} fb$^{{-1}}$)'
)

hep.histplot(
    h_sig,
    bins=bins,
    ax=ax,
    histtype='step',
    linewidth=3,
    color='red',
    label=f'Signal (Normalizado)\nBR={BR:.1e}'
)

ax.set_xlabel(var_name.replace('_', ' '), fontsize=20)
ax.set_ylabel(f"Events / bin", fontsize=20)
ax.set_xlim(xmin, xmax)
ax.legend(loc='upper right', fontsize=16)
hep.label.exp_label(exp="CMS", data=True, lumi=L_data_fb, year=2024, ax=ax)

plt.tight_layout()
plt.show()
# Out:
# Eventos esperados: 54824.93
# Scale Factor: 0.0578

# %%
import zfit

# %%
mass_min_bkg, mass_max_bkg = 5.416657231, 5.6
mass_bkg = df.query(f"{mass_min_bkg} <= BToTrkTrkMuMu_fit_mass_Kpi_good <= {mass_max_bkg}")["BToTrkTrkMuMu_fit_mass_Kpi_good"].to_numpy()
print(f"Eventos no sideband: {len(mass_bkg)}")
# Out:
# Eventos no sideband: 116689

# %%
from zfit.loss import UnbinnedNLL

obs_bkg = zfit.Space("BToTrkTrkMuMu_fit_mass_Kpi_good", limits=(mass_min_bkg, mass_max_bkg))
tau_bkg = zfit.Parameter("tau_bkg", -0.003, -0.2, -1e-6)
bkg_pdf = zfit.pdf.Exponential(lambda_=tau_bkg, obs=obs_bkg)

data_bkg = zfit.Data.from_numpy(obs=obs_bkg, array=mass_bkg)
loss_bkg = UnbinnedNLL(model=bkg_pdf, data=data_bkg)
minim = zfit.minimize.Minuit()
result = minim.minimize(loss_bkg)
result.hesse()

print(result)

bins = 50
vals, edges = np.histogram(mass_bkg, bins=bins, range=(mass_min_bkg, mass_max_bkg))
centers = 0.5*(edges[:-1] + edges[1:])
width = edges[1] - edges[0]

pdf_vals = zfit.run(bkg_pdf.pdf(centers))
pdf_scaled = pdf_vals * len(mass_bkg) * width 

plt.figure(figsize=(10,8))
plt.bar(centers, vals, width=width, color='gray', alpha=0.4, label='Dados')
plt.plot(centers, pdf_scaled, 'r-', lw=2, label='Ajuste exponencial')
plt.xlabel("B0_M [MeV/c²]")
plt.ylabel("Eventos por bin")
plt.title("Ajuste exponencial no sideband [5400, 5600] MeV")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# FitResult of
# <UnbinnedNLL model=[<zfit.<class 'zfit.models.basic.Exponential'>  params=[tau_bkg, tau_bkg]] data=[<zfit.Data: Data obs=('BToTrkTrkMuMu_fit_mass_Kpi_good',) shape=(116689, 1)>] constraints=[]>
# with
# <Minuit Minuit tol=0.001>
#
# ╒═════════╤═════════════╤══════════════════╤═════════╤══════════════════════════════╕
# │  valid  │  converged  │  param at limit  │   edm   │   approx. fmin (full | opt.) │
# ╞═════════╪═════════════╪══════════════════╪═════════╪══════════════════════════════╡
# │  True   │    True     │      False       │ 0.00018 │       -197952.19 |  9998.858 │
# ╘═════════╧═════════════╧══════════════════╧═════════╧══════════════════════════════╛
#
# Parameters
# name       value  (rounded)        hesse    at limit
# -------  ------------------  -----------  ----------
# tau_bkg          -0.0876498  +/-   0.055       False
# /tmp/ipykernel_5184/3308580194.py:22: DeprecationWarning: __call__ (from zfit.util.execution) is deprecated and will be removed in a future version.
# Instructions for updating:
# The `run(...)` method originates from the old `tf.Session` API in TF1 and is not needed anymore. In most cases, it can simply be removed. It's current functionality converts the input to numpy, which most of the time is not needed anyways.Alternatively, use `znp.asarray(...)` to convert to zfit-friendly array (that acts nearly like numpy) or `np.asarray(...) if a numpy array is *really needed*.
#   pdf_vals = zfit.run(bkg_pdf.pdf(centers))

# %%
mass_min_sig, mass_max_sig = 5.133542769 , 5.416657231

N_fit_bkg_simple = len(mass_bkg)


tau_val_bkg_simple = float(tau_bkg.value())

def integral_exp(lmbda, a, b):
    if abs(lmbda) < 1e-12:
        return b - a
    return (np.exp(lmbda * b) - np.exp(lmbda * a)) / lmbda

num = integral_exp(tau_val_bkg_simple, mass_min_sig, mass_max_sig)
den = integral_exp(tau_val_bkg_simple, mass_min_bkg, mass_max_bkg)
frac = num / den

B_est = N_fit_bkg_simple * frac
print(f"Background estimado em [{mass_min_sig:.5f}, {mass_max_sig:.5f}] MeV:")
print(f"N_bkg_simple = {B_est:.1f} eventos")
# Out:
# Background estimado em [5.13354, 5.41666] MeV:
# N_bkg_simple = 183913.1 eventos

# %%
mass_min_bkg, mass_max_bkg = 5.133542769, 5.416657231
mass_bkg = df.query(f"{mass_min_bkg} <= BToTrkTrkMuMu_fit_mass_Kpi_good <= {mass_max_bkg}")["BToTrkTrkMuMu_fit_mass_Kpi_good"].to_numpy()
print(f"Eventos na região de sinal MC: {len(mass_bkg) * scale_factor}")
# Out:
# Eventos na região de sinal MC: 9219.09229758752

# %%
import numpy as np
import matplotlib.pyplot as plt
import zfit
from zfit.loss import UnbinnedNLL
from zfit.minimize import Minuit

# %%
cuts = np.linspace(0, 1, 101)

mass_min_bkg, mass_max_bkg = 5.416657231, 5.6
mass_min_sig, mass_max_sig = 5.133542769, 5.416657231

B_est_list = []
S_est_list = []
FoM_list = []

# %%
def integral_exp(lmbda, a, b):
    if abs(lmbda) < 1e-12:
        return b - a
    return (np.exp(lmbda * b) - np.exp(lmbda * a)) / lmbda

# %%
for cut_value in cuts:

    df_cut = df[df["bdt_score"] > cut_value]

    # -------------------------
    # BACKGROUND (sideband)
    # -------------------------
    mass_bkg = df_cut.query(
        f"{mass_min_bkg} <= BToTrkTrkMuMu_fit_mass_Kpi_good <= {mass_max_bkg}"
    )["BToTrkTrkMuMu_fit_mass_Kpi_good"].to_numpy()

    N_bkg_sb = len(mass_bkg)
    print(f"\nBDT > {cut_value:.2f} | Sideband: {N_bkg_sb} eventos")

    # proteção contra estatística baixa
    if N_bkg_sb < 10:
        print("Estatística insuficiente no sideband → pulando")
        B_est_list.append(0.0)
        S_est_list.append(0.0)
        FoM_list.append(0.0)
        continue

    obs_bkg = zfit.Space(
        "BToTrkTrkMuMu_fit_mass_Kpi_good",
        limits=(mass_min_bkg, mass_max_bkg)
    )

    tau_bkg = zfit.Parameter(
        f"tau_bkg_{cut_value:.2f}", -0.003, -0.2, -1e-6
    )

    bkg_pdf = zfit.pdf.Exponential(lambda_=tau_bkg, obs=obs_bkg)

    data_bkg = zfit.Data.from_numpy(obs=obs_bkg, array=mass_bkg)

    loss_bkg = UnbinnedNLL(model=bkg_pdf, data=data_bkg)
    minim = Minuit()
    result = minim.minimize(loss_bkg)
    result.hesse()

    tau_val = float(tau_bkg.value())

    # extrapolação para a região de sinal
    frac = (
        integral_exp(tau_val, mass_min_sig, mass_max_sig)
        / integral_exp(tau_val, mass_min_bkg, mass_max_bkg)
    )

    B_est = N_bkg_sb * frac
    B_est_list.append(B_est)

    print(f"B estimado na região de sinal: {B_est:.2f}")

    # -------------------------
    # SIGNAL (MC)
    # -------------------------
    mass_signal = df_cut.query(
        f"{mass_min_sig} <= BToTrkTrkMuMu_fit_mass_Kpi_good <= {mass_max_sig}"
    )["BToTrkTrkMuMu_fit_mass_Kpi_good"].to_numpy()

    S_est = len(mass_signal) * scale_factor
    S_est_list.append(S_est)

    print(f"S estimado (MC escalado): {S_est:.2f}")

    # -------------------------
    # FoM
    # -------------------------
    fom = S_est / np.sqrt(S_est + B_est) if (S_est + B_est) > 0 else 0.0
    FoM_list.append(fom)

    print(f"FoM = {fom:.3f}")
# Out:
# BDT > 0.00 | Sideband: 116689 eventos
# B estimado na região de sinal: 183913.11
# S estimado (MC escalado): 9219.09
# FoM = 20.978
#
# BDT > 0.01 | Sideband: 76210 eventos
# B estimado na região de sinal: 120354.46
# S estimado (MC escalado): 9206.27
# FoM = 25.577
#
# BDT > 0.02 | Sideband: 51534 eventos
# B estimado na região de sinal: 81790.77
# S estimado (MC escalado): 9179.76
# FoM = 30.436
#
# BDT > 0.03 | Sideband: 40660 eventos
# B estimado na região de sinal: 63807.16
# S estimado (MC escalado): 9155.97
# FoM = 33.896
#
# BDT > 0.04 | Sideband: 34261 eventos
# B estimado na região de sinal: 53915.85
# S estimado (MC escalado): 9136.74
# FoM = 36.386
#
# BDT > 0.05 | Sideband: 29885 eventos
# B estimado na região de sinal: 47242.53
# S estimado (MC escalado): 9117.97
# FoM = 38.407
#
# BDT > 0.06 | Sideband: 26571 eventos
# B estimado na região de sinal: 41710.76
# S estimado (MC escalado): 9101.39
# FoM = 40.376
#
# BDT > 0.07 | Sideband: 24019 eventos
# B estimado na região de sinal: 38134.46
# S estimado (MC escalado): 9085.68
# FoM = 41.811
#
# BDT > 0.08 | Sideband: 21901 eventos
# B estimado na região de sinal: 34696.63
# S estimado (MC escalado): 9070.32
# FoM = 43.356
#
# BDT > 0.09 | Sideband: 20213 eventos
# B estimado na região de sinal: 31895.72
# S estimado (MC escalado): 9055.36
# FoM = 44.748
#
# BDT > 0.10 | Sideband: 18768 eventos
# B estimado na região de sinal: 29273.01
# S estimado (MC escalado): 9040.52
# FoM = 46.187
#
# BDT > 0.11 | Sideband: 17510 eventos
# B estimado na região de sinal: 27302.00
# S estimado (MC escalado): 9025.16
# FoM = 47.352
#
# BDT > 0.12 | Sideband: 16425 eventos
# B estimado na região de sinal: 25399.55
# S estimado (MC escalado): 9011.53
# FoM = 48.579
#
# BDT > 0.13 | Sideband: 15463 eventos
# B estimado na região de sinal: 24079.25
# S estimado (MC escalado): 8997.44
# FoM = 49.472
#
# BDT > 0.14 | Sideband: 14610 eventos
# B estimado na região de sinal: 23006.25
# S estimado (MC escalado): 8983.06
# FoM = 50.225
#
# BDT > 0.15 | Sideband: 13884 eventos
# B estimado na região de sinal: 21789.92
# S estimado (MC escalado): 8969.49
# FoM = 51.142
#
# BDT > 0.16 | Sideband: 13201 eventos
# B estimado na região de sinal: 20643.35
# S estimado (MC escalado): 8955.51
# FoM = 52.054
#
# BDT > 0.17 | Sideband: 12517 eventos
# B estimado na região de sinal: 19607.84
# S estimado (MC escalado): 8942.17
# FoM = 52.922
#
# BDT > 0.18 | Sideband: 11941 eventos
# B estimado na região de sinal: 18624.75
# S estimado (MC escalado): 8930.56
# FoM = 53.799
#
# BDT > 0.19 | Sideband: 11416 eventos
# B estimado na região de sinal: 17975.42
# S estimado (MC escalado): 8918.61
# FoM = 54.384
#
# BDT > 0.20 | Sideband: 10938 eventos
# B estimado na região de sinal: 17311.97
# S estimado (MC escalado): 8906.48
# FoM = 55.005
#
# BDT > 0.21 | Sideband: 10433 eventos
# B estimado na região de sinal: 16551.83
# S estimado (MC escalado): 8891.46
# FoM = 55.743
#
# BDT > 0.22 | Sideband: 10040 eventos
# B estimado na região de sinal: 15936.91
# S estimado (MC escalado): 8879.11
# FoM = 56.364
#
# BDT > 0.23 | Sideband: 9624 eventos
# B estimado na região de sinal: 15296.39
# S estimado (MC escalado): 8866.28
# FoM = 57.039
#
# BDT > 0.24 | Sideband: 9262 eventos
# B estimado na região de sinal: 14726.14
# S estimado (MC escalado): 8852.71
# FoM = 57.652
#
# BDT > 0.25 | Sideband: 8863 eventos
# B estimado na região de sinal: 14236.68
# S estimado (MC escalado): 8842.32
# FoM = 58.205
#
# BDT > 0.26 | Sideband: 8524 eventos
# B estimado na região de sinal: 13569.70
# S estimado (MC escalado): 8831.34
# FoM = 59.006
#
# BDT > 0.27 | Sideband: 8214 eventos
# B estimado na região de sinal: 13159.08
# S estimado (MC escalado): 8820.43
# FoM = 59.495
#
# BDT > 0.28 | Sideband: 7926 eventos
# B estimado na região de sinal: 12508.61
# S estimado (MC escalado): 8810.15
# FoM = 60.340
#
# BDT > 0.29 | Sideband: 7674 eventos
# B estimado na região de sinal: 12273.89
# S estimado (MC escalado): 8798.02
# FoM = 60.608
#
# BDT > 0.30 | Sideband: 7387 eventos
# B estimado na região de sinal: 11818.91
# S estimado (MC escalado): 8786.30
# FoM = 61.209
#
# BDT > 0.31 | Sideband: 7117 eventos
# B estimado na região de sinal: 11515.58
# S estimado (MC escalado): 8772.84
# FoM = 61.591
#
# BDT > 0.32 | Sideband: 6867 eventos
# B estimado na região de sinal: 11111.10
# S estimado (MC escalado): 8761.41
# FoM = 62.151
#
# BDT > 0.33 | Sideband: 6655 eventos
# B estimado na região de sinal: 10768.04
# S estimado (MC escalado): 8750.78
# FoM = 62.635
#
# BDT > 0.34 | Sideband: 6465 eventos
# B estimado na região de sinal: 10460.63
# S estimado (MC escalado): 8739.86
# FoM = 63.074
#
# BDT > 0.35 | Sideband: 6263 eventos
# B estimado na região de sinal: 10133.80
# S estimado (MC escalado): 8728.08
# FoM = 63.552
#
# BDT > 0.36 | Sideband: 6061 eventos
# B estimado na região de sinal: 9806.96
# S estimado (MC escalado): 8716.36
# FoM = 64.044
#
# BDT > 0.37 | Sideband: 5860 eventos
# B estimado na região de sinal: 9481.73
# S estimado (MC escalado): 8705.27
# FoM = 64.551
#
# BDT > 0.38 | Sideband: 5659 eventos
# B estimado na região de sinal: 9156.50
# S estimado (MC escalado): 8694.59
# FoM = 65.075
#
# BDT > 0.39 | Sideband: 5486 eventos
# B estimado na região de sinal: 8876.58
# S estimado (MC escalado): 8682.40
# FoM = 65.522
#
# BDT > 0.40 | Sideband: 5278 eventos
# B estimado na região de sinal: 8540.03
# S estimado (MC escalado): 8671.89
# FoM = 66.100
#
# BDT > 0.41 | Sideband: 5115 eventos
# B estimado na região de sinal: 8276.29
# S estimado (MC escalado): 8657.97
# FoM = 66.532
#
# BDT > 0.42 | Sideband: 4968 eventos
# B estimado na região de sinal: 8038.44
# S estimado (MC escalado): 8645.96
# FoM = 66.936
#
# BDT > 0.43 | Sideband: 4837 eventos
# B estimado na região de sinal: 7826.47
# S estimado (MC escalado): 8634.12
# FoM = 67.297
#
# BDT > 0.44 | Sideband: 4685 eventos
# B estimado na região de sinal: 7516.79
# S estimado (MC escalado): 8623.09
# FoM = 67.875
#
# BDT > 0.45 | Sideband: 4531 eventos
# B estimado na região de sinal: 7247.69
# S estimado (MC escalado): 8610.62
# FoM = 68.376
#
# BDT > 0.46 | Sideband: 4393 eventos
# B estimado na região de sinal: 7054.12
# S estimado (MC escalado): 8598.72
# FoM = 68.729
#
# BDT > 0.47 | Sideband: 4260 eventos
# B estimado na região de sinal: 6892.86
# S estimado (MC escalado): 8588.21
# FoM = 69.024
#
# BDT > 0.48 | Sideband: 4141 eventos
# B estimado na região de sinal: 6700.31
# S estimado (MC escalado): 8575.16
# FoM = 69.382
#
# BDT > 0.49 | Sideband: 3994 eventos
# B estimado na região de sinal: 6462.46
# S estimado (MC escalado): 8562.97
# FoM = 69.857
#
# BDT > 0.50 | Sideband: 3857 eventos
# B estimado na região de sinal: 6240.78
# S estimado (MC escalado): 8550.03
# FoM = 70.303
#
# BDT > 0.51 | Sideband: 3729 eventos
# B estimado na região de sinal: 6033.68
# S estimado (MC escalado): 8536.92
# FoM = 70.723
#
# BDT > 0.52 | Sideband: 3618 eventos
# B estimado na região de sinal: 5854.08
# S estimado (MC escalado): 8524.05
# FoM = 71.088
#
# BDT > 0.53 | Sideband: 3514 eventos
# B estimado na região de sinal: 5685.80
# S estimado (MC escalado): 8511.22
# FoM = 71.432
#
# BDT > 0.54 | Sideband: 3403 eventos
# B estimado na região de sinal: 5506.20
# S estimado (MC escalado): 8496.27
# FoM = 71.800
#
# BDT > 0.55 | Sideband: 3274 eventos
# B estimado na região de sinal: 5297.47
# S estimado (MC escalado): 8483.56
# FoM = 72.267
#
# BDT > 0.56 | Sideband: 3168 eventos
# B estimado na região de sinal: 5125.96
# S estimado (MC escalado): 8469.41
# FoM = 72.637
#
# BDT > 0.57 | Sideband: 3075 eventos
# B estimado na região de sinal: 4974.36
# S estimado (MC escalado): 8454.68
# FoM = 72.958
#
# BDT > 0.58 | Sideband: 2982 eventos
# B estimado na região de sinal: 4825.00
# S estimado (MC escalado): 8440.42
# FoM = 73.283
#
# BDT > 0.59 | Sideband: 2869 eventos
# B estimado na região de sinal: 4640.80
# S estimado (MC escalado): 8426.79
# FoM = 73.716
#
# BDT > 0.60 | Sideband: 2756 eventos
# B estimado na região de sinal: 4459.33
# S estimado (MC escalado): 8411.89
# FoM = 74.145
#
# BDT > 0.61 | Sideband: 2668 eventos
# B estimado na região de sinal: 4316.94
# S estimado (MC escalado): 8395.43
# FoM = 74.461
#
# BDT > 0.62 | Sideband: 2592 eventos
# B estimado na região de sinal: 4193.97
# S estimado (MC escalado): 8378.68
# FoM = 74.724
#
# BDT > 0.63 | Sideband: 2510 eventos
# B estimado na região de sinal: 4061.29
# S estimado (MC escalado): 8360.55
# FoM = 75.014
#
# BDT > 0.64 | Sideband: 2431 eventos
# B estimado na região de sinal: 3933.46
# S estimado (MC escalado): 8344.15
# FoM = 75.305
#
# BDT > 0.65 | Sideband: 2358 eventos
# B estimado na região de sinal: 3815.34
# S estimado (MC escalado): 8326.94
# FoM = 75.568
#
# BDT > 0.66 | Sideband: 2267 eventos
# B estimado na região de sinal: 3668.10
# S estimado (MC escalado): 8309.78
# FoM = 75.928
#
# BDT > 0.67 | Sideband: 2171 eventos
# B estimado na região de sinal: 3512.77
# S estimado (MC escalado): 8291.88
# FoM = 76.318
#
# BDT > 0.68 | Sideband: 2102 eventos
# B estimado na região de sinal: 3401.13
# S estimado (MC escalado): 8274.38
# FoM = 76.577
#
# BDT > 0.69 | Sideband: 2022 eventos
# B estimado na região de sinal: 3271.68
# S estimado (MC escalado): 8255.04
# FoM = 76.889
#
# BDT > 0.70 | Sideband: 1946 eventos
# B estimado na região de sinal: 3148.71
# S estimado (MC escalado): 8235.52
# FoM = 77.186
#
# BDT > 0.71 | Sideband: 1872 eventos
# B estimado na região de sinal: 3028.98
# S estimado (MC escalado): 8215.24
# FoM = 77.474
#
# BDT > 0.72 | Sideband: 1798 eventos
# B estimado na região de sinal: 2909.24
# S estimado (MC escalado): 8194.68
# FoM = 77.767
#
# BDT > 0.73 | Sideband: 1711 eventos
# B estimado na região de sinal: 2768.47
# S estimado (MC escalado): 8171.99
# FoM = 78.129
#
# BDT > 0.74 | Sideband: 1624 eventos
# B estimado na região de sinal: 2627.70
# S estimado (MC escalado): 8149.41
# FoM = 78.501
#
# BDT > 0.75 | Sideband: 1545 eventos
# B estimado na região de sinal: 2499.88
# S estimado (MC escalado): 8125.44
# FoM = 78.827
#
# BDT > 0.76 | Sideband: 1455 eventos
# B estimado na região de sinal: 2354.25
# S estimado (MC escalado): 8099.22
# FoM = 79.216
#
# BDT > 0.77 | Sideband: 1379 eventos
# B estimado na região de sinal: 2231.28
# S estimado (MC escalado): 8075.48
# FoM = 79.544
#
# BDT > 0.78 | Sideband: 1314 eventos
# B estimado na região de sinal: 2126.11
# S estimado (MC escalado): 8046.90
# FoM = 79.782
#
# BDT > 0.79 | Sideband: 1241 eventos
# B estimado na região de sinal: 2007.99
# S estimado (MC escalado): 8017.27
# FoM = 80.072
#
# BDT > 0.80 | Sideband: 1182 eventos
# B estimado na região de sinal: 1912.53
# S estimado (MC escalado): 7988.57
# FoM = 80.284
#
# BDT > 0.81 | Sideband: 1115 eventos
# B estimado na região de sinal: 1804.12
# S estimado (MC escalado): 7957.44
# FoM = 80.540
#
# BDT > 0.82 | Sideband: 1043 eventos
# B estimado na região de sinal: 1687.62
# S estimado (MC escalado): 7922.79
# FoM = 80.818
#
# BDT > 0.83 | Sideband: 972 eventos
# B estimado na região de sinal: 1572.74
# S estimado (MC escalado): 7887.15
# FoM = 81.092
#
# BDT > 0.84 | Sideband: 897 eventos
# B estimado na região de sinal: 1451.38
# S estimado (MC escalado): 7847.88
# FoM = 81.382
#
# BDT > 0.85 | Sideband: 833 eventos
# B estimado na região de sinal: 1347.83
# S estimado (MC escalado): 7806.42
# FoM = 81.591
#
# BDT > 0.86 | Sideband: 766 eventos
# B estimado na região de sinal: 1239.42
# S estimado (MC escalado): 7758.31
# FoM = 81.790
#
# BDT > 0.87 | Sideband: 696 eventos
# B estimado na região de sinal: 1126.16
# S estimado (MC escalado): 7706.97
# FoM = 82.002
#
# BDT > 0.88 | Sideband: 631 eventos
# B estimado na região de sinal: 1020.98
# S estimado (MC escalado): 7651.76
# FoM = 82.164
#
# BDT > 0.89 | Sideband: 577 eventos
# B estimado na região de sinal: 933.61
# S estimado (MC escalado): 7590.94
# FoM = 82.217
#
# BDT > 0.90 | Sideband: 521 eventos
# B estimado na região de sinal: 843.00
# S estimado (MC escalado): 7522.28
# FoM = 82.245
#
# BDT > 0.91 | Sideband: 459 eventos
# B estimado na região de sinal: 742.68
# S estimado (MC escalado): 7445.23
# FoM = 82.280
#
# BDT > 0.92 | Sideband: 394 eventos
# B estimado na região de sinal: 637.51
# S estimado (MC escalado): 7356.53
# FoM = 82.279
#
# BDT > 0.93 | Sideband: 333 eventos
# B estimado na região de sinal: 538.81
# S estimado (MC escalado): 7253.50
# FoM = 82.170
#
# BDT > 0.94 | Sideband: 277 eventos
# B estimado na região de sinal: 448.20
# S estimado (MC escalado): 7132.33
# FoM = 81.918
#
# BDT > 0.95 | Sideband: 215 eventos
# B estimado na região de sinal: 347.88
# S estimado (MC escalado): 6975.65
# FoM = 81.513
#
# BDT > 0.96 | Sideband: 163 eventos
# B estimado na região de sinal: 263.74
# S estimado (MC escalado): 6772.94
# FoM = 80.741
#
# BDT > 0.97 | Sideband: 108 eventos
# B estimado na região de sinal: 174.75
# S estimado (MC escalado): 6477.25
# FoM = 79.417
#
# BDT > 0.98 | Sideband: 56 eventos
# B estimado na região de sinal: 90.61
# S estimado (MC escalado): 6003.28
# FoM = 76.903
#
# BDT > 0.99 | Sideband: 12 eventos
# B estimado na região de sinal: 19.42
# S estimado (MC escalado): 4868.16
# FoM = 69.633
#
# BDT > 1.00 | Sideband: 0 eventos
# Estatística insuficiente no sideband → pulando

# %%
cuts = np.array(cuts)
FoM_list = np.array(FoM_list)

best_idx = np.argmax(FoM_list)

print("\n==============================")
print(f"Melhor threshold de BDT: {cuts[best_idx]:.2f}")
print(f"FoM máxima: {FoM_list[best_idx]:.3f}")
print(f"S = {S_est_list[best_idx]:.2f}")
print(f"B = {B_est_list[best_idx]:.2f}")
print("==============================")
# Out:
# ==============================
# Melhor threshold de BDT: 0.91
# FoM máxima: 82.280
# S = 7445.23
# B = 742.68
# ==============================

# %%
best_idx = np.argmax(FoM_list)
best_cut = cuts[best_idx]
best_fom = FoM_list[best_idx]

plt.figure(figsize=(8,6))
plt.plot(
    cuts,
    FoM_list,
    marker='o',
    markersize=4,
    linestyle='none',  
    label=r"$S/\sqrt{S+B}$"
)

plt.axvline(
    best_cut,
    color='red',
    linestyle='--',
    alpha=0.8,
    label=f"Melhor cut = {best_cut:.2f}"
)

plt.axhline(
    best_fom,
    color='red',
    linestyle='--',
    alpha=0.8,
    label=f"FoM máx = {best_fom:.3f}"
)

plt.text(
    best_cut,
    best_fom,
    f"  ({best_cut:.2f}, {best_fom:.3f})",
    color='red',
    fontsize=9,
    verticalalignment='bottom'
)
plt.xlabel("BDT cut", fontsize='large')
plt.ylabel(r"$S/\sqrt{S+B}$", fontsize='large')

plt.title(" ", fontsize=10)
plt.grid(alpha=0.3)
plt.legend(fontsize='small')
plt.tight_layout()
plt.show()
