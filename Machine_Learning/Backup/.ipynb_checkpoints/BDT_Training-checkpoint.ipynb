# %%
import uproot
import pandas as pd
import numpy as np
import awkward as ak
import matplotlib.pyplot as plt
import mplhep as hep
import os
import joblib
import json
import warnings
from xgboost import XGBClassifier
from sklearn.model_selection import (train_test_split, GridSearchCV, StratifiedKFold, learning_curve)
from sklearn.metrics import (roc_curve, auc, precision_recall_curve, average_precision_score, confusion_matrix,
                             ConfusionMatrixDisplay, classification_report, accuracy_score, f1_score)

# %%
signal_path = "/home/tandrade/Flavour_Anomalies/Data/Signal_MC.root"
bg_path     = "/home/tandrade/Flavour_Anomalies/Data/Background_Data.root"
tree_name   = "tree_ML"

# %%
features = [
    'BToTrkTrkMuMu_l_xy_sig_good', 'BToTrkTrkMuMu_dca_sig_good',
    'BToTrkTrkMuMu_trk1_dca_sig_good', 'BToTrkTrkMuMu_trk2_dca_sig_good',
    'BToTrkTrkMuMu_fit_ditrack_mass_Kpi_good', 'BToTrkTrkMuMu_fit_cos2D_good', 
    'BToTrkTrkMuMu_svprob_good', 'BToTrkTrkMuMu_fit_pt_good'
]

# %%
signal_file = uproot.open(signal_path)[tree_name]
signal_ak = signal_file.arrays(library="ak")
signal_df = ak.to_dataframe(signal_ak)

background_file = uproot.open(bg_path)[tree_name]
background_ak = background_file.arrays(library="ak")
background_df = ak.to_dataframe(background_ak)

# %%
signal_df["label"] = 1
background_df["label"] = 0

# %%
df = pd.concat([signal_df, background_df], ignore_index=True)
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df = df.dropna()

# %%
X = df[features]
y = df["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
num_background_train = (y_train == 0).sum()
num_signal_train = (y_train == 1).sum()
scale_pos_weight_train = num_background_train / num_signal_train if num_signal_train > 0 else 1

print(num_background_train, num_signal_train)
# Out:
# 144891 111697

# %%
bdt = XGBClassifier(
    use_label_encoder=False,
    eval_metric="auc",
    verbosity=0,
    random_state=42
)

# %%
xgb_param_grid = {
    "n_estimators": [50, 100, 150],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.01, 0.05, 0.1],
    "subsample": [0.6, 0.8, 1.0],
    "colsample_bytree": [0.6, 0.8, 1.0],
}

# %%
grid_search = GridSearchCV(
    estimator=bdt,
    param_grid=xgb_param_grid,
    scoring="roc_auc",
    cv=5,
    n_jobs=-1,
    verbose=1,
    return_train_score=True
)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False,
#                                      eval_metric='auc', feature_types=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=42, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'max_depth': [3, 5, 7], 'n_estimators': [50, 100, 150],
#                          'subsample': [0.6, 0.8, 1.0]},
#              return_train_score=True, scoring='roc_auc', verbose=1)

# %%
final_bdt = grid_search.best_estimator_

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

tprs = []
aucs = []
# Mantive 1000 pontos para boa resolução
mean_fpr = np.linspace(0, 1, 1000)

fig, ax = plt.subplots(figsize=(7, 6))

print("\nExecutando validação cruzada de 5 folds...")

for i, (train_index, val_index) in enumerate(cv.split(X_train, y_train)):
    X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
    y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]
    
    # Recalcular scale_pos_weight
    num_bg_fold = (y_train_fold == 0).sum()
    num_sig_fold = (y_train_fold == 1).sum()
    scale_pos_weight_fold = num_bg_fold / num_sig_fold if num_sig_fold > 0 else 1
    
    # Treinar
    fold_bdt = XGBClassifier(
        **grid_search.best_params_,
        use_label_encoder=False,
        eval_metric="auc",
        verbosity=0,
        scale_pos_weight=scale_pos_weight_fold,
        random_state=42
    )
    
    fold_bdt.fit(X_train_fold, y_train_fold)
    
    # Previsões
    y_val_proba = fold_bdt.predict_proba(X_val_fold)[:, 1]
    
    # ROC
    fpr, tpr, _ = roc_curve(y_val_fold, y_val_proba)
    roc_auc = auc(fpr, tpr)
    aucs.append(roc_auc)
    
    # Interpolar
    interp_tpr = np.interp(mean_fpr, fpr, tpr)
    interp_tpr[0] = 0.0
    tprs.append(interp_tpr)
    
    # Plot individual
    ax.plot(fpr, tpr, alpha=0.4, lw=1, label=f'Fold {i+1} (AUC = {roc_auc:.4f})')
    print(f"  Fold {i+1}: AUC = {roc_auc:.4f}")

# Plotar linha random
ax.plot([0, 1], [0, 1], 'k--', label='Random (AUC = 0.50)', lw=1)

# Calcular média e desvio padrão
mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0

# --- MELHORIA: Usar a média dos valores de AUC calculados ---
mean_auc = np.mean(aucs) # Mais preciso que calcular a área da curva média
std_auc = np.std(aucs)
std_tpr = np.std(tprs, axis=0)

# Plotar ROC média
ax.plot(mean_fpr, mean_tpr, 'b', 
        label=f'Mean ROC (AUC = {mean_auc:.4f} ± {std_auc:.4f})', 
        lw=2)

# Adicionar intervalo de confiança
tprs_upper = np.minimum(mean_tpr + std_tpr, 1)
tprs_lower = np.maximum(mean_tpr - std_tpr, 0)
ax.fill_between(mean_fpr, tprs_lower, tprs_upper, alpha=0.2, color='grey')

# Configurar gráfico
ax.set_xlabel("False Positive Rate", fontsize=12)
ax.set_ylabel("True Positive Rate", fontsize=12)
ax.set_title("", fontsize=14)

# --- AQUI ESTÁ A MUDANÇA ---
# Mudei de 'small' para 'x-small'. 
# Se ainda achar grande, pode colocar um número, ex: fontsize=10
ax.legend(loc="lower right", fontsize = 10) 

#ax.grid(True, alpha=0.3)
hep.cms.label("Work in Progress", ax=ax,fontsize=14, com=13.6, data=True)

plt.tight_layout()
plt.savefig("Plots/kfold_roc_curves.png", dpi=100, bbox_inches='tight')
print(f"\nCurvas ROC salvas: kfold_roc_curves.png")
plt.show()
plt.close()
# Out:
# Executando validação cruzada de 5 folds...
#   Fold 1: AUC = 0.9836
#   Fold 2: AUC = 0.9826
#   Fold 3: AUC = 0.9825
#   Fold 4: AUC = 0.9829
#   Fold 5: AUC = 0.9835
#
# Curvas ROC salvas: kfold_roc_curves.png

# %%
# Previsões no teste
y_test_proba = final_bdt.predict_proba(X_test)[:, 1]
y_test_pred = final_bdt.predict(X_test)

# Previsões no treino (para comparação)
y_train_proba = final_bdt.predict_proba(X_train)[:, 1]

# Calcular métricas
print("\nCalculando métricas...")

# ROC Curves
fpr_test, tpr_test, _ = roc_curve(y_test, y_test_proba)
roc_auc_test = auc(fpr_test, tpr_test)

fpr_train, tpr_train, _ = roc_curve(y_train, y_train_proba)
roc_auc_train = auc(fpr_train, tpr_train)

# Precision-Recall Curves
precision_test, recall_test, _ = precision_recall_curve(y_test, y_test_proba)
prc_auc_test = average_precision_score(y_test, y_test_proba)

precision_train, recall_train, _ = precision_recall_curve(y_train, y_train_proba)
prc_auc_train = average_precision_score(y_train, y_train_proba)

# Plot ROC e PRC lado a lado
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))

# ROC Curve
ax1.plot(fpr_test, tpr_test, label=f"Test (AUC = {roc_auc_test:.3f})", 
         color="blue", lw=2)
ax1.plot(fpr_train, tpr_train, label=f"Train (AUC = {roc_auc_train:.3f})", 
         color="red", linestyle='--', lw=2)
ax1.plot([0, 1], [0, 1], "k--", label='Random', lw=1)
ax1.set_xlabel("False Positive Rate", fontsize=12)
ax1.set_ylabel("True Positive Rate", fontsize=12)
#ax1.set_title("ROC Curves", fontsize=14)
ax1.legend(loc="lower right", fontsize=11)
#ax1.grid(True, alpha=0.3)
hep.cms.label("Work in Progress", ax=ax1, com=13.6, data=True)

# Precision-Recall Curve
ax2.plot(recall_test, precision_test, label=f"Test (AP = {prc_auc_test:.3f})", 
         color="blue", lw=2)
ax2.plot(recall_train, precision_train, label=f"Train (AP = {prc_auc_train:.3f})", 
         color="red", linestyle='--', lw=2)
ax2.set_xlabel("Recall", fontsize=12)
ax2.set_ylabel("Precision", fontsize=12)
#ax2.set_title("Precision-Recall Curves", fontsize=14)
ax2.legend(loc="lower left", fontsize=11)
#ax2.grid(True, alpha=0.3)
hep.cms.label("Work in Progress", ax=ax2, com=13.6, data=True)

plt.tight_layout()
plt.savefig("Plots/final_roc_prc_curves_TRAIN_vs_TEST.png", dpi=100, bbox_inches='tight')
print(f"Curvas ROC/PRC salvas: final_roc_prc_curves_TRAIN_vs_TEST.png")
plt.show()
plt.close()
# Out:
# Calculando métricas...
# Curvas ROC/PRC salvas: final_roc_prc_curves_TRAIN_vs_TEST.png

# %%
# Matriz de confusão normalizada
cm = confusion_matrix(y_test, y_test_pred)
cm_norm = confusion_matrix(y_test, y_test_pred, normalize='true')

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Matriz absoluta
disp1 = ConfusionMatrixDisplay(confusion_matrix=cm, 
                              display_labels=["Background", "Signal"])
disp1.plot(ax=ax1, cmap='Blues', values_format='d')
ax1.set_title("", fontsize=14)

# Matriz normalizada
disp2 = ConfusionMatrixDisplay(confusion_matrix=cm_norm, 
                              display_labels=["Background", "Signal"])
disp2.plot(ax=ax2, cmap='Blues', values_format='.2f')
ax2.set_title("", fontsize=14)

hep.cms.label("Work in Progress", ax=ax1, com=13.6, data=True, loc=0)
hep.cms.label("Work in Progress", ax=ax2, com=13.6, data=True, loc=0)

plt.tight_layout()
plt.savefig("Plots/final_confusion_matrix_TEST.png", dpi=100, bbox_inches='tight')
print(f"Matriz de confusão salva: final_confusion_matrix_TEST.png")
plt.show()
plt.close()

# Report de classificação
print("\n=== Classification Report (Test Set) ===")
print(classification_report(y_test, y_test_pred, 
                           target_names=['Background', 'Signal'],
                           digits=4))

print(f"Accuracy: {accuracy_score(y_test, y_test_pred):.4f}")
print(f"F1-Score: {f1_score(y_test, y_test_pred):.4f}")
# Out:
# Matriz de confusão salva: final_confusion_matrix_TEST.png
# === Classification Report (Test Set) ===
#               precision    recall  f1-score   support
#
#   Background     0.9395    0.9599    0.9496     62096
#       Signal     0.9465    0.9198    0.9330     47871
#
#     accuracy                         0.9425    109967
#    macro avg     0.9430    0.9399    0.9413    109967
# weighted avg     0.9426    0.9425    0.9424    109967
#
# Accuracy: 0.9425
# F1-Score: 0.9330

# %%
# Plotar apenas o feature importance normalizado pelo weight
imp_type = 'weight'  # Selecionar apenas o tipo weight

fig, ax = plt.subplots(figsize=(9, 6))  # Ajustei o tamanho para um único gráfico

try:
    # Obter importância pelo weight
    importance = final_bdt.get_booster().get_score(importance_type=imp_type)
    imp_df = pd.DataFrame.from_dict(importance, orient='index', 
                                   columns=[imp_type]).reindex(features).fillna(0)
    
    # Normalizar
    imp_df['Normalized'] = imp_df[imp_type] / imp_df[imp_type].max()
    imp_df = imp_df.sort_values('Normalized', ascending=True)
    
    # Plot
    bars = ax.barh(imp_df.index, imp_df['Normalized'], color='skyblue', edgecolor='black')
    
    # Adicionar valores
    for bar in bars:
        width = bar.get_width()
        ax.text(width + 0.01, bar.get_y() + bar.get_height()/2,
               f'{width:.3f}', va='center', color='black', fontsize=9)
    
    ax.set_xlabel("Normalized Importance (Weight)", fontsize=12)
    ax.set_title(" ", fontsize=14)
    ax.set_xlim(right=imp_df['Normalized'].max() * 1.15)
    #ax.grid(True, alpha=0.3, axis='x')
    ax.tick_params(axis='y', labelsize=9)
    
    # Adicionar label CMS
    hep.cms.label("Work in Progress", ax=ax, com=13.6, data=True, fontsize=12)
    
except Exception as e:
    ax.text(0.5, 0.5, f'Weight importance not available\n{str(e)}', 
           ha='center', va='center', transform=ax.transAxes, fontsize=12)
    ax.set_title(" ", fontsize=14)

plt.tight_layout()
plt.savefig('Plots/feature_importances_weight.png', dpi=100, bbox_inches='tight')
print(f"Importância das features (weight) salva: feature_importances_weight.png")
plt.show()
plt.close()
# Out:
# Importância das features (weight) salva: feature_importances_weight.png

# %%
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
from scipy.stats import ks_2samp

plt.style.use(hep.style.ROOT)

# 1. Obter as probabilidades (garantindo que não haja NaNs)
y_probs_train = final_bdt.predict_proba(X_train)[:, 1]
y_probs_test = final_bdt.predict_proba(X_test)[:, 1]

# 2. Separar Sinal e Background
sig_train = y_probs_train[y_train == 1]
bkg_train = y_probs_train[y_train == 0]
sig_test = y_probs_test[y_test == 1]
bkg_test = y_probs_test[y_test == 0]

# 3. Calcular KS Test
ks_sig = ks_2samp(sig_train, sig_test)
ks_bkg = ks_2samp(bkg_train, bkg_test)

# 4. Configurar Plot
fig, ax = plt.subplots(figsize=(7, 6))
bins = np.linspace(0, 1, 40)
bin_centers = 0.5 * (bins[:-1] + bins[1:])

# --- BACKGROUND (Vermelho) ---

# A) Treino: Calcular histograma no Numpy PRIMEIRO
# density=True aqui retorna os valores já normalizados
h_bkg_train, _ = np.histogram(bkg_train, bins=bins, density=True)

hep.histplot(h_bkg_train, bins=bins, 
             ax=ax, color='red', alpha=0.4, histtype='fill', 
             label='Bkg Train')

# B) Teste: Pontos com erro
h_bkg_test_counts, _ = np.histogram(bkg_test, bins=bins) # Contagens puras para o erro
h_bkg_test_dens, _   = np.histogram(bkg_test, bins=bins, density=True) # Densidade para o plot

# Cálculo do erro na escala de densidade:
# Erro_contagem = sqrt(N)
# Fator_escala = Densidade / Contagem
# Erro_densidade = sqrt(N) * (Densidade / N)
scale_bkg = np.divide(h_bkg_test_dens, h_bkg_test_counts, out=np.zeros_like(h_bkg_test_dens), where=h_bkg_test_counts!=0)
error_bkg = np.sqrt(h_bkg_test_counts) * scale_bkg

ax.errorbar(bin_centers, h_bkg_test_dens, yerr=error_bkg, 
            fmt='o', color='red', markersize=4, label=f'Bkg Test')


# --- SIGNAL (Azul) ---

# A) Treino
h_sig_train, _ = np.histogram(sig_train, bins=bins, density=True)

hep.histplot(h_sig_train, bins=bins, 
             ax=ax, color='blue', linewidth=2, histtype='step', 
             label='Sig Train')

# B) Teste
h_sig_test_counts, _ = np.histogram(sig_test, bins=bins)
h_sig_test_dens, _   = np.histogram(sig_test, bins=bins, density=True)

scale_sig = np.divide(h_sig_test_dens, h_sig_test_counts, out=np.zeros_like(h_sig_test_dens), where=h_sig_test_counts!=0)
error_sig = np.sqrt(h_sig_test_counts) * scale_sig

ax.errorbar(bin_centers, h_sig_test_dens, yerr=error_sig, 
            fmt='o', color='blue', markersize=4, label=f'Sig Test')

# --- Decoração ---
ax.set_yscale('log')
# Definir limites seguros para log
max_y = max(h_sig_train.max(), h_bkg_train.max())
ax.set_ylim(bottom=1e-3, top=max_y * 50) 
ax.set_xlim(0, 1)

ax.set_xlabel("BDT Output Score", fontsize=14)
ax.set_ylabel("a.u", fontsize=16)
ax.legend(loc='upper center', fontsize=12, ncol=2)

hep.cms.label("Work in Progress", ax=ax, com=13.6, data=True, fontsize=12)

plt.tight_layout()
plt.savefig("Plots/overtraining_check.png")
print("Plot salvo como overtraining_check.png")
plt.show()
# Out:
# Plot salvo como overtraining_check.png

# %%
train_sizes, train_scores, val_scores = learning_curve(
    final_bdt, X_train, y_train,
    cv=5, scoring='roc_auc', n_jobs=-1,
    train_sizes=np.linspace(0.1, 1.0, 10),
    random_state=42
)

fig, ax = plt.subplots(figsize=(7, 5))

# Calcular médias e desvios
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
val_mean = np.mean(val_scores, axis=1)
val_std = np.std(val_scores, axis=1)

# Plotar
ax.plot(train_sizes, train_mean, 'o-', color='blue', label='Training score', lw=2)
ax.plot(train_sizes, val_mean, 'o-', color='red', label='Validation score', lw=2)

# Adicionar intervalos de confiança
ax.fill_between(train_sizes, 
                 train_mean - train_std,
                 train_mean + train_std,
                 alpha=0.1, color='blue')
ax.fill_between(train_sizes,
                 val_mean - val_std,
                 val_mean + val_std,
                 alpha=0.1, color='red')

ax.set_xlabel('Training Size', fontsize=12)
ax.set_ylabel('AUC Score', fontsize=12)
ax.set_title(' ', fontsize=14)
ax.legend(loc='best', fontsize=11)
#ax.grid(True, alpha=0.3)
hep.cms.label("Work in Progress", ax=ax, com=13.6, data=True, fontsize=12)

plt.tight_layout()
plt.savefig('Plots/learning_curves.png', dpi=100, bbox_inches='tight')
print(f"Learning curves salvas: learning_curves.png")
plt.show()
plt.close()
# Out:
# Learning curves salvas: learning_curves.png

# %%
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np
from xgboost import XGBClassifier

# Definir estilo
plt.style.use(hep.style.ROOT)

# 1. Configurar parâmetros (Sem use_label_encoder)
params = grid_search.best_params_.copy()
#params['n_estimators'] = 500
params['eval_metric'] = ["logloss", "auc"]
#params['early_stopping_rounds'] = 20

# 2. Instanciar o modelo
model_monitor = XGBClassifier(
    **params,
    random_state=42
)

# 3. Treinar
print("Treinando modelo com monitoramento...")
model_monitor.fit(
    X_train, y_train,
    eval_set=[(X_train, y_train), (X_test, y_test)],
    verbose=False
)

# 4. Recuperar resultados
results = model_monitor.evals_result()
epochs = len(results['validation_0']['logloss'])

# --- MUDANÇA AQUI: Eixo X em Porcentagem ---
# Cria um array de 0 a 100 distribuído pelo número de épocas (árvores)
x_axis = np.linspace(0, 100, epochs)

# --- PLOTAR EM DOIS GRÁFICOS SEPARADOS ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# --- Gráfico 1: Log Loss ---
ax1.plot(x_axis, results['validation_0']['logloss'], label='Train', color='blue', linestyle='--')
ax1.plot(x_axis, results['validation_1']['logloss'], label='Test', color='blue', linewidth=2)
ax1.set_xlabel('Porcentagem de Árvores Treinadas (%)', fontsize=14) # Eixo alterado
ax1.set_ylabel('Log Loss', fontsize=14)
ax1.set_title(f' ', fontsize=16)
ax1.legend()
#ax1.grid(True, alpha=0.3)
ax1.set_xlim(0, 100) # Forçar limites
hep.cms.label(loc=0, ax=ax1, data=True, label="Preliminary", rlabel="")

# --- Gráfico 2: AUC ---
ax2.plot(x_axis, results['validation_0']['auc'], label='Train', color='red', linestyle='--')
ax2.plot(x_axis, results['validation_1']['auc'], label='Test', color='red', linewidth=2)
ax2.set_xlabel('Porcentagem de Árvores Treinadas (%)', fontsize=14) # Eixo alterado
ax2.set_ylabel('AUC Score', fontsize=14)
ax2.set_title(f' ', fontsize=16)
ax2.legend(loc='lower right')
#ax2.grid(True, alpha=0.3)
ax2.set_xlim(0, 100) # Forçar limites
hep.cms.label(loc=0, ax=ax2, data=True, label="Preliminary", rlabel="")

plt.tight_layout()
plt.savefig("Plots/learning_curve_percentage.png")
print("Plot salvo como: learning_curve_percentage.png")
plt.show()
# Out:
# Treinando modelo com monitoramento...
# Plot salvo como: learning_curve_percentage.png

# %%
model_filename = "final_bdt_model.joblib"
joblib.dump(final_bdt, model_filename)
print(f"Modelo salvo: {model_filename}")
# Out:
# Modelo salvo: final_bdt_model.joblib

# %%
df["bdt_score"] = final_bdt.predict_proba(df[features])[:, 1]

# %%
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np

# Configura o estilo (usando LHCb2 conforme seu snippet)
hep.style.use(hep.style.LHCb2)

# --- 1. Constantes e Normalização ---
L_data_fb = 5.01
sigma_pb  = 17370000 
BR        = 6.30e-7
N_mc_gen  = 949314      

L_data_pb = L_data_fb * 1000 
n_expected = L_data_pb * sigma_pb * BR
scale_factor = n_expected / N_mc_gen

print(f"Eventos esperados: {n_expected:.2f}")
print(f"Scale Factor: {scale_factor:.4f}")

# --- 2. Seleção de Dados no DataFrame ---
# Variável que vamos plotar e o corte do BDT
var_name = 'BToTrkTrkMuMu_fit_mass_Kpi_good'
corte_bdt = 0.

# Assumindo que no seu df você tem uma coluna 'label' ou 'category' 
# onde 1 = Signal (MC) e 0 = Background (Data)
# Se os nomes forem diferentes, ajuste 'label' == 1 abaixo.

# A) Filtrar Background (Dados Reais) -> Apenas corte de BDT
mask_bkg = (df['label'] == 0) & (df['bdt_score'] > corte_bdt)
data_bkg = df[mask_bkg][var_name]

# B) Filtrar Signal (MC) -> Corte de BDT
mask_sig = (df['label'] == 1) & (df['bdt_score'] > corte_bdt)
data_sig = df[mask_sig][var_name]

# --- 3. Preparação dos Histogramas ---
# Definir range e bins iguais para ambos
xmin, xmax = data_bkg.min(), data_bkg.max() # Ou fixe manualmente ex: 1000, 2000
bins = np.linspace(xmin, xmax, 60)

# Histograma Background (Sem pesos ou peso=1)
h_bkg, _ = np.histogram(data_bkg, bins=bins)

# Histograma Signal (COM PESOS de normalização)
# Criamos um array de pesos do mesmo tamanho dos eventos que passaram no corte
weights_sig = np.full(len(data_sig), scale_factor)
h_sig, _ = np.histogram(data_sig, bins=bins, weights=weights_sig)

# --- 4. Plotagem ---
fig, ax = plt.subplots(figsize=(10, 8))

# Plot Background
hep.histplot(
    h_bkg,
    bins=bins,
    ax=ax,
    histtype='fill',
    color='gray',
    alpha=0.5,
    edgecolor='black',
    label=f'Background (Data {L_data_fb} fb$^{{-1}}$)'
)

# Plot Signal Normalizado
hep.histplot(
    h_sig,
    bins=bins,
    ax=ax,
    histtype='step',
    linewidth=3,
    color='red',
    label=f'Signal (Normalizado)\nBR={BR:.1e}'
)

# --- 5. Estilo e Etiquetas ---
ax.set_xlabel(var_name.replace('_', ' '), fontsize=20) # Melhora label automatico
ax.set_ylabel(f"Events / bin", fontsize=20)
ax.set_xlim(xmin, xmax)
ax.legend(loc='upper right', fontsize=16)

# Label do experimento (CMS conforme seu snippet)
hep.label.exp_label(exp="CMS", data=True, lumi=L_data_fb, year=2024, ax=ax)

plt.tight_layout()
plt.show()
# Out:
# Eventos esperados: 54824.93
# Scale Factor: 0.0578

# %%
import zfit

# %%
mass_min_bkg, mass_max_bkg = 5.416657231, 5.6
mass_bkg = df.query(f"{mass_min_bkg} <= BToTrkTrkMuMu_fit_mass_Kpi_good <= {mass_max_bkg}")["BToTrkTrkMuMu_fit_mass_Kpi_good"].to_numpy()
print(f"Eventos no sideband: {len(mass_bkg)}")
# Out:
# Eventos no sideband: 116650

# %%
from zfit.loss import UnbinnedNLL

obs_bkg = zfit.Space("BToTrkTrkMuMu_fit_mass_Kpi_good", limits=(mass_min_bkg, mass_max_bkg))
tau_bkg = zfit.Parameter("tau_bkg", -0.003, -0.2, -1e-6)
bkg_pdf = zfit.pdf.Exponential(lambda_=tau_bkg, obs=obs_bkg)

data_bkg = zfit.Data.from_numpy(obs=obs_bkg, array=mass_bkg)
loss_bkg = UnbinnedNLL(model=bkg_pdf, data=data_bkg)
minim = Minuit()
result = minim.minimize(loss_bkg)
result.hesse()

print(result)

bins = 50
vals, edges = np.histogram(mass_bkg, bins=bins, range=(mass_min_bkg, mass_max_bkg))
centers = 0.5*(edges[:-1] + edges[1:])
width = edges[1] - edges[0]

pdf_vals = zfit.run(bkg_pdf.pdf(centers))
pdf_scaled = pdf_vals * len(mass_bkg) * width 

plt.figure(figsize=(10,8))
plt.bar(centers, vals, width=width, color='gray', alpha=0.4, label='Dados')
plt.plot(centers, pdf_scaled, 'r-', lw=2, label='Ajuste exponencial')
plt.xlabel("B0_M [MeV/c²]")
plt.ylabel("Eventos por bin")
plt.title("Ajuste exponencial no sideband [5400, 5600] MeV")
plt.legend()
plt.grid(alpha=0.3)
plt.show()
# Out:
# FitResult of
# <UnbinnedNLL model=[<zfit.<class 'zfit.models.basic.Exponential'>  params=[tau_bkg, tau_bkg]] data=[<zfit.Data: Data obs=('BToTrkTrkMuMu_fit_mass_Kpi_good',) shape=(116650, 1)>] constraints=[]>
# with
# <Minuit Minuit tol=0.001>
#
# ╒═════════╤═════════════╤══════════════════╤═════════╤══════════════════════════════╕
# │  valid  │  converged  │  param at limit  │   edm   │   approx. fmin (full | opt.) │
# ╞═════════╪═════════════╪══════════════════╪═════════╪══════════════════════════════╡
# │  True   │    True     │      False       │ 0.00018 │        -197886.02 |  9998.87 │
# ╘═════════╧═════════════╧══════════════════╧═════════╧══════════════════════════════╛
#
# Parameters
# name       value  (rounded)        hesse    at limit
# -------  ------------------  -----------  ----------
# tau_bkg          -0.0872125  +/-   0.055       False

# %%
# limites da janela de interesse
mass_min_sig, mass_max_sig = 5.133542769 , 5.416657231

N_fit_bkg_simple = len(mass_bkg)


tau_val_bkg_simple = float(tau_bkg.value())

def integral_exp(lmbda, a, b):
    if abs(lmbda) < 1e-12:
        return b - a
    return (np.exp(lmbda * b) - np.exp(lmbda * a)) / lmbda

# fração da área da exponencial entre as regiões
num = integral_exp(tau_val_bkg_simple, mass_min_sig, mass_max_sig)
den = integral_exp(tau_val_bkg_simple, mass_min_bkg, mass_max_bkg)
frac = num / den

# estimativa de background na janela de sinal
B_est = N_fit_bkg_simple * frac
print(f"Background estimado em [{mass_min_sig:.5f}, {mass_max_sig:.5f}] MeV:")
print(f"N_bkg_simple = {B_est:.1f} eventos")
# Out:
# Background estimado em [5.13354, 5.41666] MeV:
# N_bkg_simple = 183832.9 eventos

# %%
mass_min_bkg, mass_max_bkg = 5.133542769, 5.416657231
mass_bkg = df.query(f"{mass_min_bkg} <= BToTrkTrkMuMu_fit_mass_Kpi_good <= {mass_max_bkg}")["BToTrkTrkMuMu_fit_mass_Kpi_good"].to_numpy()
print(f"Eventos na região de sinal MC: {len(mass_bkg) * scale_factor}")
# Out:
# Eventos na região de sinal MC: 9215.396159551

# %%
B_est_list
# Out:
# [np.float64(183832.86960018246),
#  np.float64(29732.692918438523),
#  np.float64(16951.918879728684),
#  np.float64(11894.22842549825),
#  np.float64(8268.54900730229),
#  np.float64(6153.415750440874),
#  np.float64(4441.526751238439),
#  np.float64(3119.586002325152),
#  np.float64(1886.6375926897758),
#  np.float64(825.2016914821816)]

# %%
S_est_list
# Out:
# [9215.396159551,
#  9215.396159551,
#  9215.396159551,
#  9215.396159551,
#  9215.396159551,
#  9215.396159551,
#  9215.396159551,
#  9215.396159551,
#  9215.396159551,
#  9215.396159551]

# %%
FoM = []
def FoM(S, B):
    for S,B in S_est_lis, B_est_lis
    threshold = S/np.sqrt(S+B)
    FoM.appen(threshold)
    return FoM

# %%
import numpy as np
import matplotlib.pyplot as plt
import zfit
from zfit.loss import UnbinnedNLL
from zfit.minimize import Minuit

# %%
cuts = np.linspace(0, 1, 101)

mass_min_bkg, mass_max_bkg = 5.416657231, 5.6
mass_min_sig, mass_max_sig = 5.133542769, 5.416657231

B_est_list = []
S_est_list = []
FoM_list = []

# %%
def integral_exp(lmbda, a, b):
    if abs(lmbda) < 1e-12:
        return b - a
    return (np.exp(lmbda * b) - np.exp(lmbda * a)) / lmbda

# %%
for cut_value in cuts:

    df_cut = df[df["bdt_score"] > cut_value]

    # -------------------------
    # BACKGROUND (sideband)
    # -------------------------
    mass_bkg = df_cut.query(
        f"{mass_min_bkg} <= BToTrkTrkMuMu_fit_mass_Kpi_good <= {mass_max_bkg}"
    )["BToTrkTrkMuMu_fit_mass_Kpi_good"].to_numpy()

    N_bkg_sb = len(mass_bkg)
    print(f"\nBDT > {cut_value:.2f} | Sideband: {N_bkg_sb} eventos")

    # proteção contra estatística baixa
    if N_bkg_sb < 10:
        print("Estatística insuficiente no sideband → pulando")
        B_est_list.append(0.0)
        S_est_list.append(0.0)
        FoM_list.append(0.0)
        continue

    obs_bkg = zfit.Space(
        "BToTrkTrkMuMu_fit_mass_Kpi_good",
        limits=(mass_min_bkg, mass_max_bkg)
    )

    tau_bkg = zfit.Parameter(
        f"tau_bkg_{cut_value:.2f}", -0.003, -0.2, -1e-6
    )

    bkg_pdf = zfit.pdf.Exponential(lambda_=tau_bkg, obs=obs_bkg)

    data_bkg = zfit.Data.from_numpy(obs=obs_bkg, array=mass_bkg)

    loss_bkg = UnbinnedNLL(model=bkg_pdf, data=data_bkg)
    minim = Minuit()
    result = minim.minimize(loss_bkg)
    result.hesse()

    tau_val = float(tau_bkg.value())

    # extrapolação para a região de sinal
    frac = (
        integral_exp(tau_val, mass_min_sig, mass_max_sig)
        / integral_exp(tau_val, mass_min_bkg, mass_max_bkg)
    )

    B_est = N_bkg_sb * frac
    B_est_list.append(B_est)

    print(f"B estimado na região de sinal: {B_est:.2f}")

    # -------------------------
    # SIGNAL (MC)
    # -------------------------
    mass_signal = df_cut.query(
        f"{mass_min_sig} <= BToTrkTrkMuMu_fit_mass_Kpi_good <= {mass_max_sig}"
    )["BToTrkTrkMuMu_fit_mass_Kpi_good"].to_numpy()

    S_est = len(mass_signal) * scale_factor
    S_est_list.append(S_est)

    print(f"S estimado (MC escalado): {S_est:.2f}")

    # -------------------------
    # FoM
    # -------------------------
    fom = S_est / np.sqrt(S_est + B_est) if (S_est + B_est) > 0 else 0.0
    FoM_list.append(fom)

    print(f"FoM = {fom:.3f}")
# Out:
# BDT > 0.00 | Sideband: 116650 eventos
# B estimado na região de sinal: 183832.87
# S estimado (MC escalado): 9215.40
# FoM = 20.974
#
# BDT > 0.01 | Sideband: 74340 eventos
# B estimado na região de sinal: 117123.78
# S estimado (MC escalado): 9203.15
# FoM = 25.893
#
# BDT > 0.02 | Sideband: 51242 eventos
# B estimado na região de sinal: 81096.79
# S estimado (MC escalado): 9178.90
# FoM = 30.550
#
# BDT > 0.03 | Sideband: 40563 eventos
# B estimado na região de sinal: 63885.00
# S estimado (MC escalado): 9157.76
# FoM = 33.884
#
# BDT > 0.04 | Sideband: 34204 eventos
# B estimado na região de sinal: 54254.18
# S estimado (MC escalado): 9137.37
# FoM = 36.292
#
# BDT > 0.05 | Sideband: 29698 eventos
# B estimado na região de sinal: 47459.05
# S estimado (MC escalado): 9119.87
# FoM = 38.341
#
# BDT > 0.06 | Sideband: 26439 eventos
# B estimado na região de sinal: 41944.32
# S estimado (MC escalado): 9101.74
# FoM = 40.285
#
# BDT > 0.07 | Sideband: 23914 eventos
# B estimado na região de sinal: 37894.62
# S estimado (MC escalado): 9086.26
# FoM = 41.920
#
# BDT > 0.08 | Sideband: 21935 eventos
# B estimado na região de sinal: 34762.66
# S estimado (MC escalado): 9071.25
# FoM = 43.327
#
# BDT > 0.09 | Sideband: 20231 eventos
# B estimado na região de sinal: 31663.64
# S estimado (MC escalado): 9058.25
# FoM = 44.888
#
# BDT > 0.10 | Sideband: 18761 eventos
# B estimado na região de sinal: 29732.69
# S estimado (MC escalado): 9044.39
# FoM = 45.930
#
# BDT > 0.11 | Sideband: 17528 eventos
# B estimado na região de sinal: 27712.49
# S estimado (MC escalado): 9028.91
# FoM = 47.104
#
# BDT > 0.12 | Sideband: 16525 eventos
# B estimado na região de sinal: 26023.28
# S estimado (MC escalado): 9013.49
# FoM = 48.154
#
# BDT > 0.13 | Sideband: 15550 eventos
# B estimado na região de sinal: 24208.81
# S estimado (MC escalado): 9000.44
# FoM = 49.389
#
# BDT > 0.14 | Sideband: 14666 eventos
# B estimado na região de sinal: 22957.00
# S estimado (MC escalado): 8986.99
# FoM = 50.283
#
# BDT > 0.15 | Sideband: 13874 eventos
# B estimado na região de sinal: 21471.85
# S estimado (MC escalado): 8974.34
# FoM = 51.432
#
# BDT > 0.16 | Sideband: 13182 eventos
# B estimado na região de sinal: 20355.42
# S estimado (MC escalado): 8960.88
# FoM = 52.335
#
# BDT > 0.17 | Sideband: 12520 eventos
# B estimado na região de sinal: 19333.23
# S estimado (MC escalado): 8947.37
# FoM = 53.205
#
# BDT > 0.18 | Sideband: 11945 eventos
# B estimado na região de sinal: 18445.32
# S estimado (MC escalado): 8934.14
# FoM = 53.993
#
# BDT > 0.19 | Sideband: 11362 eventos
# B estimado na região de sinal: 17545.04
# S estimado (MC escalado): 8921.61
# FoM = 54.840
#
# BDT > 0.20 | Sideband: 10870 eventos
# B estimado na região de sinal: 16951.92
# S estimado (MC escalado): 8909.31
# FoM = 55.401
#
# BDT > 0.21 | Sideband: 10411 eventos
# B estimado na região de sinal: 16083.44
# S estimado (MC escalado): 8897.12
# FoM = 56.292
#
# BDT > 0.22 | Sideband: 9959 eventos
# B estimado na região de sinal: 15378.51
# S estimado (MC escalado): 8884.30
# FoM = 57.036
#
# BDT > 0.23 | Sideband: 9596 eventos
# B estimado na região de sinal: 14973.95
# S estimado (MC escalado): 8871.25
# FoM = 57.449
#
# BDT > 0.24 | Sideband: 9244 eventos
# B estimado na região de sinal: 14692.33
# S estimado (MC escalado): 8858.37
# FoM = 57.723
#
# BDT > 0.25 | Sideband: 8882 eventos
# B estimado na região de sinal: 14000.26
# S estimado (MC escalado): 8845.84
# FoM = 58.524
#
# BDT > 0.26 | Sideband: 8565 eventos
# B estimado na região de sinal: 13723.53
# S estimado (MC escalado): 8834.00
# FoM = 58.818
#
# BDT > 0.27 | Sideband: 8216 eventos
# B estimado na região de sinal: 13293.56
# S estimado (MC escalado): 8822.16
# FoM = 59.323
#
# BDT > 0.28 | Sideband: 7920 eventos
# B estimado na região de sinal: 12814.87
# S estimado (MC escalado): 8812.34
# FoM = 59.923
#
# BDT > 0.29 | Sideband: 7632 eventos
# B estimado na região de sinal: 12348.90
# S estimado (MC escalado): 8800.33
# FoM = 60.513
#
# BDT > 0.30 | Sideband: 7351 eventos
# B estimado na região de sinal: 11894.23
# S estimado (MC escalado): 8788.26
# FoM = 61.108
#
# BDT > 0.31 | Sideband: 7083 eventos
# B estimado na região de sinal: 11460.41
# S estimado (MC escalado): 8775.84
# FoM = 61.691
#
# BDT > 0.32 | Sideband: 6837 eventos
# B estimado na região de sinal: 11062.56
# S estimado (MC escalado): 8764.01
# FoM = 62.241
#
# BDT > 0.33 | Sideband: 6589 eventos
# B estimado na região de sinal: 10484.41
# S estimado (MC escalado): 8751.99
# FoM = 63.102
#
# BDT > 0.34 | Sideband: 6373 eventos
# B estimado na região de sinal: 10088.88
# S estimado (MC escalado): 8741.19
# FoM = 63.701
#
# BDT > 0.35 | Sideband: 6187 eventos
# B estimado na região de sinal: 9766.75
# S estimado (MC escalado): 8728.43
# FoM = 64.181
#
# BDT > 0.36 | Sideband: 5971 eventos
# B estimado na região de sinal: 9312.93
# S estimado (MC escalado): 8716.01
# FoM = 64.913
#
# BDT > 0.37 | Sideband: 5777 eventos
# B estimado na região de sinal: 9062.70
# S estimado (MC escalado): 8703.89
# FoM = 65.300
#
# BDT > 0.38 | Sideband: 5603 eventos
# B estimado na região de sinal: 8790.36
# S estimado (MC escalado): 8690.83
# FoM = 65.732
#
# BDT > 0.39 | Sideband: 5408 eventos
# B estimado na região de sinal: 8539.25
# S estimado (MC escalado): 8679.69
# FoM = 66.146
#
# BDT > 0.40 | Sideband: 5227 eventos
# B estimado na região de sinal: 8268.55
# S estimado (MC escalado): 8667.62
# FoM = 66.603
#
# BDT > 0.41 | Sideband: 5088 eventos
# B estimado na região de sinal: 8113.93
# S estimado (MC escalado): 8655.20
# FoM = 66.838
#
# BDT > 0.42 | Sideband: 4911 eventos
# B estimado na região de sinal: 7945.05
# S estimado (MC escalado): 8644.34
# FoM = 67.115
#
# BDT > 0.43 | Sideband: 4775 eventos
# B estimado na região de sinal: 7726.15
# S estimado (MC escalado): 8632.97
# FoM = 67.496
#
# BDT > 0.44 | Sideband: 4642 eventos
# B estimado na região de sinal: 7510.95
# S estimado (MC escalado): 8620.95
# FoM = 67.875
#
# BDT > 0.45 | Sideband: 4488 eventos
# B estimado na região de sinal: 7261.77
# S estimado (MC escalado): 8609.17
# FoM = 68.338
#
# BDT > 0.46 | Sideband: 4353 eventos
# B estimado na região de sinal: 7043.34
# S estimado (MC escalado): 8597.16
# FoM = 68.743
#
# BDT > 0.47 | Sideband: 4197 eventos
# B estimado na região de sinal: 6790.92
# S estimado (MC escalado): 8584.28
# FoM = 69.230
#
# BDT > 0.48 | Sideband: 4061 eventos
# B estimado na região de sinal: 6570.87
# S estimado (MC escalado): 8570.30
# FoM = 69.649
#
# BDT > 0.49 | Sideband: 3921 eventos
# B estimado na região de sinal: 6344.34
# S estimado (MC escalado): 8557.25
# FoM = 70.100
#
# BDT > 0.50 | Sideband: 3803 eventos
# B estimado na região de sinal: 6153.42
# S estimado (MC escalado): 8544.49
# FoM = 70.479
#
# BDT > 0.51 | Sideband: 3685 eventos
# B estimado na região de sinal: 5962.49
# S estimado (MC escalado): 8531.78
# FoM = 70.867
#
# BDT > 0.52 | Sideband: 3579 eventos
# B estimado na região de sinal: 5790.97
# S estimado (MC escalado): 8518.39
# FoM = 71.211
#
# BDT > 0.53 | Sideband: 3460 eventos
# B estimado na região de sinal: 5598.43
# S estimado (MC escalado): 8506.60
# FoM = 71.626
#
# BDT > 0.54 | Sideband: 3337 eventos
# B estimado na região de sinal: 5399.41
# S estimado (MC escalado): 8495.00
# FoM = 72.068
#
# BDT > 0.55 | Sideband: 3216 eventos
# B estimado na região de sinal: 5203.62
# S estimado (MC escalado): 8480.79
# FoM = 72.498
#
# BDT > 0.56 | Sideband: 3112 eventos
# B estimado na região de sinal: 5035.35
# S estimado (MC escalado): 8466.41
# FoM = 72.863
#
# BDT > 0.57 | Sideband: 3024 eventos
# B estimado na região de sinal: 4892.96
# S estimado (MC escalado): 8452.03
# FoM = 73.165
#
# BDT > 0.58 | Sideband: 2931 eventos
# B estimado na região de sinal: 4742.48
# S estimado (MC escalado): 8437.59
# FoM = 73.495
#
# BDT > 0.59 | Sideband: 2844 eventos
# B estimado na região de sinal: 4601.71
# S estimado (MC escalado): 8422.46
# FoM = 73.801
#
# BDT > 0.60 | Sideband: 2745 eventos
# B estimado na região de sinal: 4441.53
# S estimado (MC escalado): 8408.14
# FoM = 74.174
#
# BDT > 0.61 | Sideband: 2669 eventos
# B estimado na região de sinal: 4318.56
# S estimado (MC escalado): 8392.02
# FoM = 74.436
#
# BDT > 0.62 | Sideband: 2584 eventos
# B estimado na região de sinal: 4181.02
# S estimado (MC escalado): 8375.33
# FoM = 74.743
#
# BDT > 0.63 | Sideband: 2497 eventos
# B estimado na região de sinal: 4040.25
# S estimado (MC escalado): 8360.61
# FoM = 75.078
#
# BDT > 0.64 | Sideband: 2411 eventos
# B estimado na região de sinal: 3901.10
# S estimado (MC escalado): 8342.30
# FoM = 75.394
#
# BDT > 0.65 | Sideband: 2322 eventos
# B estimado na região de sinal: 3757.09
# S estimado (MC escalado): 8323.76
# FoM = 75.730
#
# BDT > 0.66 | Sideband: 2237 eventos
# B estimado na região de sinal: 3619.56
# S estimado (MC escalado): 8307.53
# FoM = 76.068
#
# BDT > 0.67 | Sideband: 2157 eventos
# B estimado na região de sinal: 3490.12
# S estimado (MC escalado): 8289.05
# FoM = 76.374
#
# BDT > 0.68 | Sideband: 2059 eventos
# B estimado na região de sinal: 3331.55
# S estimado (MC escalado): 8271.32
# FoM = 76.788
#
# BDT > 0.69 | Sideband: 1988 eventos
# B estimado na região de sinal: 3216.67
# S estimado (MC escalado): 8252.15
# FoM = 77.056
#
# BDT > 0.70 | Sideband: 1928 eventos
# B estimado na região de sinal: 3119.59
# S estimado (MC escalado): 8231.24
# FoM = 77.259
#
# BDT > 0.71 | Sideband: 1842 eventos
# B estimado na região de sinal: 2980.43
# S estimado (MC escalado): 8210.16
# FoM = 77.611
#
# BDT > 0.72 | Sideband: 1770 eventos
# B estimado na região de sinal: 2863.94
# S estimado (MC escalado): 8188.27
# FoM = 77.888
#
# BDT > 0.73 | Sideband: 1689 eventos
# B estimado na região de sinal: 2732.87
# S estimado (MC escalado): 8165.52
# FoM = 78.217
#
# BDT > 0.74 | Sideband: 1610 eventos
# B estimado na região de sinal: 2605.05
# S estimado (MC escalado): 8142.42
# FoM = 78.542
#
# BDT > 0.75 | Sideband: 1527 eventos
# B estimado na região de sinal: 2470.75
# S estimado (MC escalado): 8119.26
# FoM = 78.898
#
# BDT > 0.76 | Sideband: 1448 eventos
# B estimado na região de sinal: 2342.93
# S estimado (MC escalado): 8095.24
# FoM = 79.235
#
# BDT > 0.77 | Sideband: 1381 eventos
# B estimado na região de sinal: 2234.52
# S estimado (MC escalado): 8069.25
# FoM = 79.494
#
# BDT > 0.78 | Sideband: 1299 eventos
# B estimado na região de sinal: 2101.84
# S estimado (MC escalado): 8041.70
# FoM = 79.846
#
# BDT > 0.79 | Sideband: 1229 eventos
# B estimado na região de sinal: 1988.57
# S estimado (MC escalado): 8012.07
# FoM = 80.118
#
# BDT > 0.80 | Sideband: 1166 eventos
# B estimado na região de sinal: 1886.64
# S estimado (MC escalado): 7983.48
# FoM = 80.358
#
# BDT > 0.81 | Sideband: 1087 eventos
# B estimado na região de sinal: 1758.81
# S estimado (MC escalado): 7954.09
# FoM = 80.708
#
# BDT > 0.82 | Sideband: 1040 eventos
# B estimado na região de sinal: 1682.76
# S estimado (MC escalado): 7917.36
# FoM = 80.806
#
# BDT > 0.83 | Sideband: 969 eventos
# B estimado na região de sinal: 1567.88
# S estimado (MC escalado): 7881.03
# FoM = 81.076
#
# BDT > 0.84 | Sideband: 900 eventos
# B estimado na região de sinal: 1456.24
# S estimado (MC escalado): 7840.38
# FoM = 81.316
#
# BDT > 0.85 | Sideband: 840 eventos
# B estimado na região de sinal: 1359.16
# S estimado (MC escalado): 7798.74
# FoM = 81.494
#
# BDT > 0.86 | Sideband: 774 eventos
# B estimado na região de sinal: 1252.36
# S estimado (MC escalado): 7752.07
# FoM = 81.694
#
# BDT > 0.87 | Sideband: 712 eventos
# B estimado na região de sinal: 1152.05
# S estimado (MC escalado): 7697.90
# FoM = 81.828
#
# BDT > 0.88 | Sideband: 644 eventos
# B estimado na região de sinal: 1042.02
# S estimado (MC escalado): 7639.74
# FoM = 81.993
#
# BDT > 0.89 | Sideband: 576 eventos
# B estimado na região de sinal: 931.99
# S estimado (MC escalado): 7579.05
# FoM = 82.153
#
# BDT > 0.90 | Sideband: 510 eventos
# B estimado na região de sinal: 825.20
# S estimado (MC escalado): 7512.92
# FoM = 82.276
#
# BDT > 0.91 | Sideband: 445 eventos
# B estimado na região de sinal: 720.03
# S estimado (MC escalado): 7434.26
# FoM = 82.327
#
# BDT > 0.92 | Sideband: 373 eventos
# B estimado na região de sinal: 603.53
# S estimado (MC escalado): 7345.38
# FoM = 82.387
#
# BDT > 0.93 | Sideband: 314 eventos
# B estimado na região de sinal: 508.07
# S estimado (MC escalado): 7240.73
# FoM = 82.256
#
# BDT > 0.94 | Sideband: 257 eventos
# B estimado na região de sinal: 415.84
# S estimado (MC escalado): 7114.26
# FoM = 81.984
#
# BDT > 0.95 | Sideband: 201 eventos
# B estimado na região de sinal: 325.23
# S estimado (MC escalado): 6957.86
# FoM = 81.530
#
# BDT > 0.96 | Sideband: 147 eventos
# B estimado na região de sinal: 237.85
# S estimado (MC escalado): 6743.55
# FoM = 80.708
#
# BDT > 0.97 | Sideband: 98 eventos
# B estimado na região de sinal: 158.57
# S estimado (MC escalado): 6443.58
# FoM = 79.302
#
# BDT > 0.98 | Sideband: 48 eventos
# B estimado na região de sinal: 77.67
# S estimado (MC escalado): 5939.52
# FoM = 76.569
#
# BDT > 0.99 | Sideband: 8 eventos
# Estatística insuficiente no sideband → pulando
#
# BDT > 1.00 | Sideband: 0 eventos
# Estatística insuficiente no sideband → pulando

# %%
cuts = np.array(cuts)
FoM_list = np.array(FoM_list)

best_idx = np.argmax(FoM_list)

print("\n==============================")
print(f"Melhor threshold de BDT: {cuts[best_idx]:.2f}")
print(f"FoM máxima: {FoM_list[best_idx]:.3f}")
print(f"S = {S_est_list[best_idx]:.2f}")
print(f"B = {B_est_list[best_idx]:.2f}")
print("==============================")
# Out:
# ==============================
# Melhor threshold de BDT: 0.92
# FoM máxima: 82.387
# S = 7345.38
# B = 603.53
# ==============================

# %%
plt.figure(figsize=(8,6))
plt.plot(cuts, FoM_list)
plt.xlabel("BDT cut")
plt.ylabel(r"$S/\sqrt{S+B}$")
plt.title("Figure of Merit vs BDT threshold")
plt.grid(alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.plot(
    cuts,
    FoM_list,
    marker='o',
    markersize=4,   # ↓ marcador menor
    label=r"$S/\sqrt{S+B}$"
)

plt.axvline(
    best_cut,
    color='red',
    linestyle='--',
    alpha=0.8,
    label=f"Melhor cut = {best_cut:.2f}"
)

plt.axhline(
    best_fom,
    color='red',
    linestyle='--',
    alpha=0.8,
    label=f"FoM máx = {best_fom:.3f}"
)

plt.text(
    best_cut,
    best_fom,
    f"  ({best_cut:.2f}, {best_fom:.3f})",
    color='red',
    fontsize=11,
    verticalalignment='bottom'
)

plt.xlabel("BDT cut")
plt.ylabel(r"$S/\sqrt{S+B}$")
plt.title("Figure of Merit vs BDT threshold")
plt.grid(alpha=0.3)
plt.legend()
plt.tight_layout()
plt.show()
